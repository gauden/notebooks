# %% [markdown]
# # Long-term consequences of the most serious incident of physical and/or sexual violence by a partner since the age of 15

# %% [markdown]
# Source: [Violence against women survey results](http://fra.europa.eu/en/vaw-survey-results)
#
# View this notebook on [nbviewer](http://nbviewer.ipython.org/github/gauden/notebooks/blob/master/vaw.ipynb)

# %% [markdown]
# ##  Citation

# %% [raw]
# `@ONLINE{EF:2012:Online,
# 	author = {
#             European Union Agency for Fundamental Rights
#           FRA gender-based violence against women survey dataset, 2012},
# 	title = {Long-term psychological consequences of the most serious incident of physical and/or sexual violence by a partner since the age of 15* ‡ ( Consequences of physical and sexual violence) visualisation : EU bar chart by :  All,  All - FRA gender-based violence against women survey dataset, 2012},
# 	year = {2012},
# 	url = {http://fra.europa.eu/en/vaw-survey-results?locale=EN&dataSource=VAW&media=png&width=740&plot=euBars&topic=2.+Consequences+of+physical+and+sexual+violence&question=DVS_B02&superSubset=1&subset=AllSubset&subsetValue=01--All}
# }`

# %% [markdown]
# ##  Setup

# %%
from __future__ import print_function, unicode_literals, division

# %%
import os

import numpy as np
import pandas as pd

import requests
import pycountry
# Out:
# /Users/gauden/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /Users/gauden/anaconda/lib/python2.7/argparse.pyc, but /Users/gauden/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
# (*) To communicate with Plotly's server, sign in with credentials file
import plotly.plotly as py  

# (*) Useful Python/Plotly tools
import plotly.tools as tls   

# (*) Graph objects to piece together plots
from plotly.graph_objs import *

# %% [markdown]
# ## Download and Create DataFrame

# %%
url = ('http://fra.europa.eu/DVS/render/?locale=EN&dataSource=VAW&'
       'media=xls&width=740&plot=euBars&topic=2.+Consequences+of+physical+'
       'and+sexual+violence&question=DVS_B02&superSubset=1&'
       'subset=AllSubset&subsetValue=01--All')
local_file = os.path.join('data', 'vaw.xls')

# %%
if not os.path.isfile(local_file):
    result = requests.get(url)
    if result.status_code == 200:
        with open(local_file, 'w') as fh:
            fh.write(result.content)
    else:
        raise IOError('Could not download the data. Check URL and network connection.')

# %%
data = pd.read_csv(local_file, sep='\t', header=False)
data.head()
# Out:
#   CountryCode question_code   subset                       answer  percentage
# 0          AT       DVS_B02  01. All               01. Depression          21
# 1          AT       DVS_B02  01. All                  02. Anxiety          46
# 2          AT       DVS_B02  01. All            03. Panic attacks          19
# 3          AT       DVS_B02  01. All  04. Loss of self-confidence          37
# 4          AT       DVS_B02  01. All       05. Feeling vulnerable          39

# %% [markdown]
# ##  Clean Data

# %% [markdown]
# ### Relabel Country Codes

# %%
def expand_country(code):
    try:
        expansion = pycountry.countries.get(alpha2=code).name
    except KeyError:
        if code == 'UK':
            expansion = 'United Kingdom'
        elif code == 'EL':
            expansion = 'EU Average'
        else:
            expansion = code
    return expansion

data['country'] = data.CountryCode.map(lambda x: expand_country(x))

# %% [markdown]
# ### Drop Extra Columns and Numbering of Answers

# %%
data.answer = data.answer.str[4:]
data.drop(['question_code', 'subset', 'CountryCode'], axis=1, inplace=True)

# %% [markdown]
# ### Drop rows with Averages and Answers for 'Other'

# %%
data = data[data.country.str[-6:] != 'verage']  # drop 'average' rows

# %%
data = data[data.answer != 'Other']  # drop answers with 'Other'

# %% [markdown]
# ### View Tidy Data and Table

# %%
# Calculate the order of columns based on 
# the median for each category in original dataframe
order = data.groupby('answer').median().sort(columns='percentage', ascending=False)

# %%
data.head()
# Out:
#                     answer  percentage  country
# 0               Depression          21  Austria
# 1                  Anxiety          46  Austria
# 2            Panic attacks          19  Austria
# 3  Loss of self-confidence          37  Austria
# 4       Feeling vulnerable          39  Austria

# %%
data.pivot(index='answer', columns='country', values='percentage').T
# Out:
# answer          Anxiety  Concentration difficulties  Depression  \
# country
# Austria              46                          20          21
# Belgium              29                          15          20
# Bulgaria             43                          11          28
# Croatia              40                          23          30
# Cyprus               48                          21          24
# Czech Republic       35                           7          17
# Denmark              23                          16          13
# Estonia              32                          10          35
# Finland              34                          12          23
# France               30                          13          22
# Germany              36                          13          20
# Hungary              43                          13          19
# Ireland              35                          18          33
# Italy                38                           8          15
# Latvia               48                           8          17
# Lithuania            38                          14          22
# Luxembourg           36                          28          35
# Malta                28                          17          23
# Netherlands          28                          15          21
# Poland               52                          27          34
# Portugal             33                          10          34
# Romania              44                          22          24
# Slovakia             41                           9          24
# Slovenia             34                          12          28
# Spain                39                          18          30
# Sweden               19                           9          15
# United Kingdom       29                          15          34
#
# answer          Difficulties in relationships  Difficulty in sleeping  \
# country
# Austria                                    32                      38
# Belgium                                    36                      32
# Bulgaria                                   24                      21
# Croatia                                    18                      31
# Cyprus                                     23                      26
# Czech Republic                             17                      19
# Denmark                                    38                      21
# Estonia                                    42                      28
# Finland                                    29                      22
# France                                     28                      32
# Germany                                    45                      28
# Hungary                                    23                      23
# Ireland                                    31                      36
# Italy                                       8                      18
# Latvia                                     30                      15
# Lithuania                                  14                      26
# Luxembourg                                 31                      45
# Malta                                      37                      27
# Netherlands                                39                      23
# Poland                                     20                      37
# Portugal                                   13                      32
# Romania                                    24                      33
# Slovakia                                   19                      22
# Slovenia                                   32                      34
# Spain                                      26                      28
# Sweden                                     33                      19
# United Kingdom                             30                      30
#
# answer          Feeling vulnerable  Loss of self-confidence  Panic attacks
# country
# Austria                         39                       37             19
# Belgium                         31                       36             15
# Bulgaria                        30                       36             24
# Croatia                         49                       32             20
# Cyprus                          27                       24             24
# Czech Republic                  33                       22             10
# Denmark                         46                       37              8
# Estonia                         30                       34             17
# Finland                         34                       34              7
# France                          28                       34             15
# Germany                         43                       33             13
# Hungary                         40                       31             10
# Ireland                         49                       55             18
# Italy                           22                       19             11
# Latvia                          16                       16             16
# Lithuania                       28                       32             22
# Luxembourg                      39                       51             28
# Malta                           36                       35             17
# Netherlands                     42                       37             11
# Poland                          44                       47             26
# Portugal                        28                       23             17
# Romania                         27                       36             22
# Slovakia                        46                       28              9
# Slovenia                        47                       30             15
# Spain                           26                       35             14
# Sweden                          31                       18             10
# United Kingdom                  40                       55             14

# %%
data = data.pivot(index='answer', columns='country', values='percentage').T

# %%
data = data[order.index]

# %%
data.head()
# Out:
# answer    Anxiety  Feeling vulnerable  Loss of self-confidence  \
# country
# Austria        46                  39                       37
# Belgium        29                  31                       36
# Bulgaria       43                  30                       36
# Croatia        40                  49                       32
# Cyprus         48                  27                       24
#
# answer    Difficulties in relationships  Difficulty in sleeping  Depression  \
# country
# Austria                              32                      38          21
# Belgium                              36                      32          20
# Bulgaria                             24                      21          28
# Croatia                              18                      31          30
# Cyprus                               23                      26          24
#
# answer    Panic attacks  Concentration difficulties
# country
# Austria              19                          20
# Belgium              15                          15
# Bulgaria             24                          11
# Croatia              20                          23
# Cyprus               24                          21

# %% [markdown]
# ## Heatmap

# %%
plotly_data = Data([
    Heatmap(
        z=data.as_matrix(),
        x=data.columns,
        y=data.index,
        name='y',
        zmin=7,
        zmax=55,
        colorscale=[[0, 'rgb(220, 220, 220)'], [0.2, 'rgb(245, 195, 157)'], [0.4, 'rgb(245, 160, 105)'], [1, 'rgb(178, 10, 28)']],
        colorbar=ColorBar(
            title='% Respondents'
        )
    )
])
layout = Layout(
    title='Psychological Consequences of Physical or Sexual Abuse',
    showlegend=False,
    autosize=False,
    width=700,
    height=1000,
    xaxis=XAxis(
        title='',
        titlefont=Font(
            family='Open Sans, sans-serif'
        ),
        range=[-0.5, 7.5],
        type='category',
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=True,
        ticks='inside',
        mirror='allticks',
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    yaxis=YAxis(
        titlefont=Font(
            family='Open Sans, sans-serif'
        ),
        range=[-0.5, 28.5],
        type='category',
        autorange='reversed',
        showgrid=False,
        zeroline=False,
        showline=True,
        ticks='inside',
        mirror='allticks',
        linecolor='rgb(34,34,34)',
        linewidth=1
    ),
    legend=Legend(
        x=0.02,
        y=1,
        bgcolor='rgba(255, 255, 255, 0.5)',
        xref='paper',
        yref='paper'
    ),
    margin=Margin(
        l=120,
        r=120,
        b=150,
        pad=0
    ),
    paper_bgcolor='white',
    plot_bgcolor='white',
    hovermode='x',
    dragmode='zoom'
)
fig = Figure(data=plotly_data, layout=layout)
py.iplot(fig, height=1000)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~gauden/94.embed" height="1000" width="100%"></iframe>

# %% [markdown]
# ## Boxplots

# %%
x_data = ['<br>'.join(label.split())
          for label in data.columns]

y_data = data.values.T

traces = []

# for xd, yd, cls in zip(x_data, y_data, colors):
for xd, yd in zip(x_data, y_data):
        traces.append(Box(
            y=yd,
            name=xd,
            boxpoints=False,
            whiskerwidth=0.2,
            marker=Marker(
                size=2,
            ),
            line=Line(width=1),
        ))

layout = Layout(
    title='Psychological Consequences of Physical or Sexual Abuse<br>(Percentage of Respondents reporting the effect)',
    yaxis=YAxis(
        autorange=True,
        showgrid=True,
        zeroline=True,
        dtick=5,
        gridcolor='rgb(255, 255, 255)',
        gridwidth=1,
        zerolinecolor='rgb(255, 255, 255)',
        zerolinewidth=2,
    ),
    margin=Margin(
        l=40,
        r=30,
        b=80,
        t=100,
    ),
    width=600,
    height=600,
    showlegend=False
)

fig = Figure(data=traces, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~gauden/96.embed" height="525" width="100%"></iframe>
