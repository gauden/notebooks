# %% [markdown]
# # Opportunity for Early Development for Girls

# %% [markdown]
# ## Setup

# %%
from __future__ import unicode_literals, print_function, division

# %%
import os

# %%
import pandas as pd

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls
# Out:
# /Users/gauden/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /Users/gauden/anaconda/lib/python2.7/argparse.pyc, but /Users/gauden/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
import plot_constants as pc

# %% [markdown]
# ## Specific Configuration

# %%
DATA_DIR = os.path.join('.', 'data')
RAW_FILE = os.path.join(DATA_DIR, 'raw_data_20150701.xlsx')

# %%
SHEET = 'Figure15'

PARSE_COLS = 'A,B,D'
SKIPROWS = 3
SKIP_FOOTER = 63-50

title = 'Opportunity for Early Development for Girls'
subtitle = 'Pre-primary School Participation, 2009-2012 (most recent year)'
source = dict(label='UNICEF', 
              link='http://www.unicef.org/sowc2011/fullreport.php',
              accessed='25 April 2015')

X_LABEL = ''
Y_LABEL = 'Precentage of official pre-primary school-aged children'

# %% [markdown]
# ## Data Importation and Munging

# %%
DF = pd.read_excel(RAW_FILE,
                   sheetname=SHEET,
                   parse_cols=PARSE_COLS,
                   skiprows=SKIPROWS,
                   skip_footer=SKIP_FOOTER)
DF.columns = ['country', 'female', 'male']
DF['gap'] = DF.male - DF.female
DF = DF.sort('gap')
DF
# Out:
#                  country  female  male  gap
# 47                 Spain     127    25 -102
# 42            San Marino     108    10  -98
# 44              Germany      112    31  -81
# 43                France     109    28  -81
# 36           Switzerland     100    56  -44
# 6                Ireland      53    17  -36
# 46               Belgium     118    84  -34
# 22       United Kingdom       85    54  -31
# 27               Estonia      91    62  -29
# 19   Republic of Moldova      79    52  -27
# 33                 Italy      97    77  -20
# 32               Iceland      96    80  -16
# 30              Slovenia      93    78  -15
# 24            Luxembourg      89    77  -12
# 45                 Malta     113   103  -10
# 37               Ukraine     100    92   -8
# 40               Austria     103    95   -8
# 31                Sweden      95    87   -8
# 34                Norway      99    92   -7
# 38              Belarus      101    95   -6
# 41                Israel     103    99   -4
# 25    Russian Federation      90    88   -2
# 28           Netherlands      91    91    0
# 3             Uzbekistan      25    25    0
# 16                Poland      78    78    0
# 13               Finland      70    71    1
# 35               Denmark     100   106    6
# 23               Hungary      87    93    6
# 29                Latvia      92    99    7
# 8                 Serbia      56    64    8
# 17               Romania      78    88   10
# 21              Portugal      85    99   14
# 20              Bulgaria      85   104   19
# 18                Greece      79    98   19
# 9                Armenia      60    79   19
# 12               Albania      69    94   25
# 39        Czech Republic     101   128   27
# 26              Slovakia      90   118   28
# 1   Bosnia & Herzegovina      16    44   28
# 7             Kazakhstan      54    86   32
# 14             Lithuania      75   110   35
# 15                Cyprus      77   113   36
# 11              Croatia       62   103   41
# 10            Montenegro      60   104   44
# 0             Tajikistan       8    69   61
# 4        TFYR Macedonia       29   104   75
# 2             Azerbaijan      25   104   79
# 5                 Turkey      30   119   89

# %% [markdown]
# ## Plotting

# %%
plot_height = pc.PLOT_HEIGHT * 0.8
plot_width = pc.PLOT_WIDTH * 1.25
filename = 'vaw/fig_08'

def make_scatter(x, y, name, fill_color, line_color, symbol, size):
    trace = Scatter(x=x,
                    y=y,
                    mode='markers',
                    name=name,
                    marker=Marker(color=fill_color,
                                  line=Line(color=line_color,
                                            width=1,
                                           ),
                                  symbol=symbol,
                                  size=size,)
                   )
    return trace

female_trace = make_scatter(x=DF.country,
                            y=DF.female,
                            name='Female',
                            fill_color=pc.FEMALE_FILL,
                            line_color=pc.FEMALE_LINE,
                            symbol=pc.FEMALE_SYMBOL,
                            size=10)

male_trace = make_scatter(x=DF.country,
                          y=DF.male,
                          name='Male',
                          fill_color=pc.MALE_FILL,
                          line_color=pc.MALE_LINE,
                          symbol=pc.MALE_SYMBOL,
                          size=12)

data = Data([male_trace, female_trace])

layout = Layout(
    title = '<b>{}</b><br>{}'.format(title, subtitle),
    autosize=False,
    width=plot_width,
    height=plot_height,
    margin=Margin(
        l=50,
        r=120,
        b=130,
        pad=0
    ),
    hovermode='x',
    xaxis=XAxis(title=X_LABEL, gridcolor='#bbbbbb'),
    yaxis=YAxis(title=Y_LABEL),
    annotations=Annotations([
        Annotation(
            x=0,
            y=-0.22,
            xref='paper',
            yref='paper',
            text='Source: <a href="{}">{}</a>'.format(source['link'],source['label']),
            align='center',
            showarrow=False
        )
    ]),
)

fig = Figure(data=data, layout=layout)
py.iplot(fig, filename=filename, height=plot_height)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~gauden/221.embed" height="800.0" width="100%"></iframe>
