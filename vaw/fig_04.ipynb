# %% [markdown]
# # Global Gender Gap for 47 Member States of the WHO European Region 2014

# %% [markdown]
# The Global Gender Gap Index presented in this Report seeks to measure one important aspect of gender equality: the relative gaps between women and men across four key areas: health, education, economy and politics.

# %% [markdown]
# ## Setup

# %%
from __future__ import unicode_literals, print_function, division

# %%
import os

# %%
import pandas as pd

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls
# Out:
# /Users/gauden/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /Users/gauden/anaconda/lib/python2.7/argparse.pyc, but /Users/gauden/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# ## Specific Configuration

# %%
DATA_DIR = os.path.join('.', 'data')
RAW_FILE = os.path.join(DATA_DIR, 'raw_data_20150701.xlsx')

# %%
SHEET = 'Figure5'

PARSE_COLS = 'A:C'
SKIPROWS = 3
SKIP_FOOTER = 61-51

title = 'Gender Gap in Selected European Countries'
subtitle = 'Global Gender Gap for 47 Member States of the WHO European Region (2014)'
source = dict(label='World Economic Forum. Global Gender Gap Report', 
              link='http://reports.weforum.org/global-gender-gap-report-2014/rankings/')

X_LABEL = 'Score (0= Inequality / 1= equality)'
Y_LABEL = ''

# %% [markdown]
# ## Data Importation and Munging

# %%
DF = pd.read_excel(RAW_FILE,
                   sheetname=SHEET,
                   parse_cols=PARSE_COLS,
                   skiprows=SKIPROWS,
                   skip_footer=SKIP_FOOTER)
DF
# Out:
#     Rank              Country   Score
# 0    125               Turkey  0.6183
# 1    103              Armenia  0.6622
# 2    102           Tajikistan  0.6654
# 3     99                Malta  0.6707
# 4     96       Czech Republic  0.6737
# 5     95               Cyprus  0.6741
# 6     94           Azerbaijan  0.6753
# 7     93              Hungary  0.6759
# 8     91               Greece  0.6784
# 9     90             Slovakia  0.6806
# 10    85              Georgia  0.6855
# 11    83              Albania  0.6869
# 12    75   Russian Federation  0.6927
# 13    74           Montenegro  0.6934
# 14    72              Romania  0.6936
# 15    70                 MKDa  0.6943
# 16    69                Italy  0.6973
# 17    67           Kyrgyzstan  0.6974
# 18    65               Israel  0.7005
# 19    62              Estonia  0.7017
# 20    57               Poland  0.7051
# 21    56              Ukraine  0.7056
# 22    55              Croatia  0.7075
# 23    54               Serbia  0.7086
# ...

# %% [markdown]
# ## Plotting
